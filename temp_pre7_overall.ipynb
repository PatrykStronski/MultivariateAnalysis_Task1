# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde 
from diagram_estimations import draw_mm_diagrams, draw_mle_diagrams, draw_ls_diagrams, draw_hist_kde

df_sampled = pd.read_csv('./data/FW_Veg_Rem_Combined.csv')

property = 'Temp_pre_7'

s_c = 'ALL'

kernel = gaussian_kde(df_sampled[property])
min_amount, max_amount = df_sampled[property].min(), df_sampled[property].max()

print(f'min value: {min_amount}; max value: {max_amount}')
# Out:
# min value: -20.84610422; max value: 55.0

# %%
x = np.linspace(min_amount, max_amount, num=50)
kde_values = kernel(x)

draw_hist_kde(df_sampled, x, s_c, property, kde_values, 50)

# %%
draw_mm_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8420775257713282, pvalue=2.3081255692660803e-40), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=10.087682991993113, pvalue=2.107931829087306e-09)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8440273638223696, pvalue=1.2132606319694868e-40), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=10.155323333337128, pvalue=2.3610213784053258e-09)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8462275602427626, pvalue=5.823121089050163e-41), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=10.228565768265394, pvalue=2.6649719098159608e-09)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.9991704371708015, pvalue=1.7518390370138776e-154), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=16.66502482043934, pvalue=5.211524545245538e-10)

# %%
draw_mle_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8458222570137722, pvalue=6.670782029510105e-41), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=10.229097780377616, pvalue=2.6673004915878096e-09)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8414732567338823, pvalue=2.8133130754268315e-40), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=10.060693399305512, pvalue=2.0138366529920404e-09)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.5168973968696161, pvalue=6.104586842397134e-13), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=4.17668016426814, pvalue=0)

# %%
draw_ls_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# [26.63545538 -3.09687206  0.58817402]
# [-2.77010168 16.53156641 10.80798462]
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.9630922939081861, pvalue=4.538189972120897e-72), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=15.056227050190616, pvalue=2.057016446066484e-09)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=1.0, pvalue=0.0), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=16.666666666666664, pvalue=5.220809340400479e-10)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8155593735980374, pvalue=7.921581773579377e-37), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=9.281413722845578, pvalue=4.579828738471292e-10)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8402035544484544, pvalue=4.255269096344643e-40), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=10.098153670273575, pvalue=2.1454689136390925e-09)

# %%
plt.boxplot(df_sampled[property], vert=False)
plt.title(f'Box with whiskers for {property} [deg Celsius]')
WHISKERS_FOLDER = './figures/whiskers/'
plt.savefig(f'{WHISKERS_FOLDER}whiskers_{property}_{s_c}.png')
plt.show()
