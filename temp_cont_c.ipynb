# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde 
from diagram_estimations import draw_mm_diagrams, draw_mle_diagrams, draw_ls_diagrams

df = pd.read_csv('./data/FW_Veg_Rem_Combined.csv')

fire_size_classes = pd.unique(df['fire_size_class'])
property = 'Temp_cont'
s_c = 'C'

df_sampled = df.loc[df['fire_size_class'] == s_c]

kernel = gaussian_kde(df_sampled[property])
min_amount, max_amount = df_sampled[property].min(), df_sampled[property].max()
x = np.linspace(0, max_amount, num=50)
kde_values = kernel(x)

draw_mm_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7306771145570321, pvalue=8.930286655058318e-28), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=6.923853824697633, pvalue=1.5191037316952816e-10)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7374279772095186, pvalue=2.108114841834093e-28), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.083768983698564, pvalue=2.3677249050280125e-10)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7536821332146607, pvalue=5.7278289711872216e-30), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.486022476370179, pvalue=6.649668593539104e-10)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7288299327480148, pvalue=1.3186939606097738e-27), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=6.952970639534882, pvalue=1.6494561272395458e-10)

# %%
draw_mle_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7531192536325523, pvalue=6.510467105402747e-30), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.482970771560442, pvalue=6.60052901224617e-10)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7497324268137635, pvalue=1.3999702703413924e-29), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.414366669490164, pvalue=5.577857065119929e-10)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7997680735673366, pvalue=6.436629636671912e-35), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=8.943549254327758, pvalue=2.2817792100227052e-10)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.5100088429415289, pvalue=1.3791489180579096e-12), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=4.164164788033417, pvalue=0)

# %%
draw_ls_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# [2.52348371e-05 5.28369786e+00 1.29246304e+01]
# [-2.48042487  1.9304277  10.20962289]
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=1.0, pvalue=0.0), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=16.666666666666664, pvalue=5.220809340400479e-10)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=1.0, pvalue=0.0), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=16.666666666666664, pvalue=5.220809340400479e-10)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.6547819441766813, pvalue=1.6116989624944048e-21), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=5.40506603808574, pvalue=2.1377977166281426e-10)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7233320993008735, pvalue=4.152859160453233e-27), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=6.651313005369166, pvalue=6.788147821623625e-11)

# %%
plt.boxplot(df_sampled[property], vert=False)
plt.show()
