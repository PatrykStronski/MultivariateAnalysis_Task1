# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde 
from diagram_estimations import draw_mm_diagrams, draw_mle_diagrams, draw_ls_diagrams, draw_hist_kde

df_sampled = pd.read_csv('./data/FW_Veg_Rem_Combined.csv')

property = 'Temp_cont'

s_c = 'ALL'

kernel = gaussian_kde(df_sampled[property])
min_amount, max_amount = df_sampled[property].min(), df_sampled[property].max()

print(f'min value: {min_amount}; max value: {max_amount}')
# Out:
# min value: -22.75; max value: 55.0

# %%
x = np.linspace(min_amount, max_amount, num=50)
kde_values = kernel(x)

draw_hist_kde(df_sampled, x, s_c, property, kde_values, 50)

# %%
draw_mm_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7502332507595008, pvalue=1.250784022937413e-29), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.430423957245593, pvalue=5.803642011414922e-10)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7548131844297457, pvalue=4.424952189499608e-30), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.5473089791264, pvalue=7.707949833957173e-10)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7687705929694473, pvalue=1.6864208162066522e-31), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.913578348687696, pvalue=1.891919954033483e-11)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7599343825269653, pvalue=1.358590577185457e-30), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.8191329293356215, pvalue=1.501777480150679e-09)

# %%
draw_mle_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7659947017959676, pvalue=3.2704458231932393e-31), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.860493933136938, pvalue=1.6461424445779471e-09)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.765259081020763, pvalue=3.8937567977811364e-31), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.842367617269781, pvalue=1.5814287657178738e-09)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8100221481911211, pvalue=3.829998770081158e-36), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=9.356434725780066, pvalue=5.309825912291899e-10)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.5246722253607693, pvalue=2.3906571005960975e-13), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=4.190032039910897, pvalue=0)

# %%
draw_ls_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# [ 1.01641971e+04 -2.12230167e+00  1.06151209e-04]
# [-3.70918364  7.80761096 10.56555501]
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.6738029199359471, pvalue=5.785687252255923e-23), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=5.895581626396921, pvalue=4.868883074493624e-12)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=1.0, pvalue=0.0), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=16.666666666666664, pvalue=5.220809340400479e-10)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8601271497921024, pvalue=4.507106621833193e-43), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=10.648194977438344, pvalue=1.123475756870107e-10)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.6081950230147586, pvalue=2.834896558141632e-18), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=4.858445189288199, pvalue=1.8791523892502937e-11)

# %%
plt.boxplot(df_sampled[property], vert=False)
plt.title(f'Box with whiskers for {property} for fire_size_class {s_c}')
plt.show()
