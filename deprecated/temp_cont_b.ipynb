# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde 
from diagram_estimations import draw_mm_diagrams, draw_mle_diagrams, draw_ls_diagrams, draw_hist_kde

df = pd.read_csv('./data/FW_Veg_Rem_Combined.csv')

fire_size_classes = pd.unique(df['fire_size_class'])
property = 'Temp_cont'
s_c = 'B'

df_sampled = df.loc[df['fire_size_class'] == s_c]

kernel = gaussian_kde(df_sampled[property])
min_amount, max_amount = df_sampled[property].min(), df_sampled[property].max()
x = np.linspace(min_amount, max_amount, num=50)
kde_values = kernel(x)

draw_hist_kde(df_sampled, x, s_c, property, kde_values, 50)

# %%
draw_mm_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7216076128604748, pvalue=5.92803626673707e-27), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=6.753553193346709, pvalue=9.253298127731568e-11)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7287895757224896, pvalue=1.329938850143666e-27), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=6.91839788799083, pvalue=1.4957324268038974e-10)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7455674124809881, pvalue=3.5482491883388645e-29), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.321800718272945, pvalue=4.4223469330972875e-10)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.714156655008871, pvalue=2.7015678588727275e-26), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=6.675586118366826, pvalue=7.312506156154086e-11)

# %%
draw_mle_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7457531038404517, pvalue=3.405044942322655e-29), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.3420501232352695, pvalue=4.655041907497548e-10)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7417677963291762, pvalue=8.199194602446758e-29), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.26834192936599, pvalue=3.857112407246177e-10)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8000371545796316, pvalue=5.986330651284497e-35), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=9.082799928670031, pvalue=3.059832387464212e-10)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.5077756084173295, pvalue=1.790653410753434e-12), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=4.16013105491045, pvalue=0)

# %%
draw_ls_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# [ 3.4431076  -2.11334933  0.9839352 ]
# [-9.97603785 23.42470738 10.17744179]
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.5171732462332777, pvalue=5.906775599094499e-13), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=4.167737732969415, pvalue=0)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=1.0, pvalue=0.0), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=16.666666666666664, pvalue=5.220809340400479e-10)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.5292131722343832, pvalue=1.3706393870826425e-13), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=4.230872781242349, pvalue=0)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.6482369421480668, pvalue=4.87084347962796e-21), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=5.3184683823294625, pvalue=1.5537671149701282e-10)

# %%
plt.boxplot(df_sampled[property], vert=False)
plt.title(f'Box with whiskers for {property} for fire_size_class {s_c}')
WHISKERS_FOLDER = './figures/whiskers/'
plt.savefig(f'{WHISKERS_FOLDER}whiskers_{property}_{s_c}.png')
plt.show()
