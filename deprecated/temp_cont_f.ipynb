# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde 
from diagram_estimations import draw_mm_diagrams, draw_mle_diagrams, draw_ls_diagrams

df = pd.read_csv('./data/FW_Veg_Rem_Combined.csv')

fire_size_classes = pd.unique(df['fire_size_class'])
property = 'Temp_cont'
s_c = 'F'

df_sampled = df.loc[df['fire_size_class'] == s_c]

kernel = gaussian_kde(df_sampled[property])
min_amount, max_amount = df_sampled[property].min(), df_sampled[property].max()
x = np.linspace(0, max_amount, num=50)
kde_values = kernel(x)

draw_mm_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.893003011678701, pvalue=5.980163552900161e-49), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=11.904287542338357, pvalue=9.028430225654915e-10)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.9083626338496076, pvalue=2.5462300307359713e-52), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=12.521168371579575, pvalue=2.3043097430175408e-09)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8871585483099308, pvalue=8.63705774577579e-48), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=11.675675418915556, pvalue=6.386970952121374e-10)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=1.0, pvalue=0.0), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=16.666666666666664, pvalue=5.220809340400479e-10)

# %%
draw_mle_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8832397940831117, pvalue=4.808537689318978e-47), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=11.525097688223704, pvalue=5.047237072730582e-10)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8843640309372586, pvalue=2.955098149309275e-47), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=11.56977022243316, pvalue=5.415791148877247e-10)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8833304192045689, pvalue=4.624243219056644e-47), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=11.528122104415647, pvalue=5.071466580020001e-10)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.5342334784832085, pvalue=7.353962086360695e-14), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=4.221123103087706, pvalue=0)

# %%
draw_ls_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# [1.00355906e-03 1.70423540e+01 1.34070171e+01]
# [ 8.97959804 31.54796181 11.38744978]
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8975837265586715, pvalue=6.667855273546071e-50), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=12.08210731751346, pvalue=1.1711960290483603e-09)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.897885633970084, pvalue=5.750943959660179e-50), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=12.09400804729831, pvalue=1.2703255114487888e-09)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8976726794714155, pvalue=6.3837511541494695e-50), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=12.085537549354143, pvalue=1.1770026064894523e-09)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=1.0, pvalue=0.0), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=16.666666666666664, pvalue=5.220809340400479e-10)

# %%
plt.boxplot(df_sampled[property], vert=False)
plt.title(f'Box with whiskers for {property} for fire_size_class {s_c}')
WHISKERS_FOLDER = './figures/whiskers/'
plt.savefig(f'{WHISKERS_FOLDER}whiskers_{property}_{s_c}.png')
plt.show()
