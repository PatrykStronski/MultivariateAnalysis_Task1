# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde 
from diagram_estimations import draw_mm_diagrams, draw_mle_diagrams, draw_ls_diagrams, draw_hist_kde

df = pd.read_csv('./data/FW_Veg_Rem_Combined.csv')

fire_size_classes = pd.unique(df['fire_size_class'])
property = 'Temp_cont'
s_c = 'D'

df_sampled = df.loc[df['fire_size_class'] == s_c]

kernel = gaussian_kde(df_sampled[property])
min_amount, max_amount = df_sampled[property].min(), df_sampled[property].max()
x = np.linspace(min_amount, max_amount, num=50)
kde_values = kernel(x)

draw_hist_kde(df_sampled, x, s_c, property, kde_values, 50)

# %%
draw_mm_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7831194861425987, pvalue=4.9420484686820393e-33), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=8.216294800186487, pvalue=4.195643832360929e-11)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7859477375127661, pvalue=2.41046276353459e-33), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=8.296915946736675, pvalue=5.136591152421488e-11)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7965762965133948, pvalue=1.5124509898400777e-34), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=8.606026778399363, pvalue=1.0773604230962519e-10)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.8262136888132205, pvalue=3.411094216108324e-38), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=9.605076403131205, pvalue=8.527448747130961e-10)

# %%
draw_mle_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7906427703811625, pvalue=7.195299219154163e-34), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=8.443438418529615, pvalue=7.346578900779832e-11)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7877204834700658, pvalue=1.5309368033822172e-33), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=8.367365307335442, pvalue=6.110478789622675e-11)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.818585299287551, pvalue=3.2934696287513735e-37), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=9.350534018597875, pvalue=5.248866896678805e-10)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.5772542202400451, pvalue=2.518488225374387e-16), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=4.466151384024648, pvalue=0)

# %%
draw_ls_diagrams(df_sampled, x, s_c, property, kde_values, 50)
# Out:
# [10.15452948 -4.08442041  1.32668369]
# [-10.87204856  17.15154219  11.09880312]
# FOR gamma: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7622167305854205, pvalue=7.973884292420939e-31), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.664265999175097, pvalue=1.0557226204355175e-09)
# FOR lognorm: Kolmogorov-Smirnoff test result KstestResult(statistic=1.0, pvalue=0.0), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=16.666666666666664, pvalue=5.220809340400479e-10)
# FOR exponnorm: Kolmogorov-Smirnoff test result KstestResult(statistic=0.7378408992220339, pvalue=1.9280303892736557e-28), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=7.051471742752894, pvalue=2.1682389217403397e-10)
# FOR expon: Kolmogorov-Smirnoff test result KstestResult(statistic=0.5281742552647042, pvalue=1.5575662112041065e-13), whereas Omega squared test (Cramér–von Mises) test CramerVonMisesResult(statistic=4.198207495756307, pvalue=0)

# %%
plt.boxplot(df_sampled[property], vert=False)
plt.title(f'Box with whiskers for {property} for fire_size_class {s_c}')
WHISKERS_FOLDER = './figures/whiskers/'
plt.savefig(f'{WHISKERS_FOLDER}whiskers_{property}_{s_c}.png')
plt.show()
